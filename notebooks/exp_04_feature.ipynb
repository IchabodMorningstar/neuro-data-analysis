# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data import *

# %%
data = load_mnm_feature(None)

# %%
data['raw_df']
# Out:
#                                                                                     ts  \
# cell                 position trial
# ADR-PFC-AD-PRE-1     0        4                                     [0.1655, 2.759575]
#                               5                   [0.3136, 4.491925, 5.3354, 5.807975]
#                               6          [0.142425, 0.86805, 1.602, 2.321125, 3.59125]
#                               7                                     [2.6982, 5.097775]
#                               8                   [0.443675, 0.61975, 0.629375, 0.769]
# ...                                                                                ...
# ELV-PFC-PV-POST-2690 7        7      [0.1358, 0.205525, 0.45975, 0.52325, 0.5281, 1...
#                               8      [0.0242, 0.3164, 0.342175, 0.3595, 0.366225, 0...
#                               9      [0.167, 0.67815, 0.773175, 0.787325, 0.849825,...
# ...
